# %%
import pandas as pd
from IPython import display
from matplotlib import pyplot as plt

data = pd.read_csv("houseprices.csv")

data.plot.scatter('size', 'price')

display.display(data)
# Out:
#    size  price
# 0  1700  51000
# 1  2100  63000
# 2  1900  57000
# 3  1300  39000
# 4  1600  48000
# 5  2200  66000

# %%
data2 = pd.read_csv("houseprices2.csv")

plt.scatter(data2['size'], data2['price']);
plt.plot(data2['size'], data2['price']);

plt.show()

display.display(data2)
# Out:
#    size  price
# 0  1700  53000
# 1  2100  65000
# 2  1900  59000
# 3  1300  41000
# 4  1600  50000
# 5  2200  68000

# %%
data3 = pd.read_csv("houseprices3.csv")

plt.scatter(data3['size'], data3['price']);
plt.plot(data3['size'], data3['price']);

plt.show()

display.display(data3)
# Out:
#    size  price
# 0  1700  53000
# 1  2100  44000
# 2  1900  59000
# 3  1300  82000
# 4  1600  50000
# 5  2200  68000
